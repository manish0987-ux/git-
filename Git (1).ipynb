# %% [raw]
# 1(a) Create a new folder
# mkdir GitAssignment1
# cd GitAssignment1
# git init
# 🔹 1(b) Create files
# touch Code.txt Log.txt Output.txt
# 🔹 1(c) Stage Code.txt and Output.txt
# git add Code.txt Output.txt
# 🔹 1(d) Commit them
# git commit -m "Added Code and Output files"
# 🔹 1(e) Push to GitHub
# git remote add origin https://github.com/manish0987-ux/Git-Assignment.git
# git branch -M main
# git push -u origin main

# %% [raw]
# 2 (1). Create working directory
# mkdir GitAssignment2
# cd GitAssignment2
# git init
# touch feature1.txt feature2.txt
# git add .
# git commit -m "Initial commit with feature files"
# 🔹 2. Create branches
# git branch develop
# git branch feature1
# git branch feature2
# 🔹 3. Create develop.txt in develop (no commit)
# git checkout develop
# touch develop.txt
# 🔹 4. Stash file & switch to feature1
# git stash
# git checkout feature1
# 🔹 5. Create new.txt, stage & commit
# touch new.txt
# git add new.txt
# git commit -m "Added new.txt in feature1"
# 🔹 6. Checkout develop, unstash & commit
# git checkout develop
# git stash pop
# git add develop.txt
# git commit -m "Added develop.txt after unstash"

# %% [raw]
# 3🔹 1. Initialize & create branches
# mkdir GitAssignment3
# cd GitAssignment3
# git init
# git branch Develop
# git branch F1
# git branch f2
# 🔹 2. Commit main.txt in master
# touch main.txt
# git add main.txt
# git commit -m "Added main.txt"
# 🔹 3. Add files in respective branches
#
# Develop branch
#
# git checkout Develop
# touch develop.txt
# git add develop.txt
# git commit -m "Added develop.txt"
#
# F1 branch
#
# git checkout F1
# touch f1.txt
# git add f1.txt
# git commit -m "Added f1.txt"
#
# f2 branch
#
# git checkout f2
# touch f2.txt
# git add f2.txt
# git commit -m "Added f2.txt"
# 🔹 4. Push all branches
# git remote add origin https://github.com/yourusername/repository.git
# git push origin master
# git push origin Develop
# git push origin F1
# git push origin f2
# 🔹 5. Delete f2 locally
# git branch -d f2
# 🔹 6. Delete f2 on GitHub
# git push origin --delete f2

# %% [raw]
# 4🔹 1. master.txt on master
# git checkout master
# touch master.txt
# git add master.txt
# git commit -m "Added master.txt"
# 🔹 2. Create branches
# git branch public1
# git branch public2
# git branch private
# 🔹 3. public1.txt in public1
# git checkout public1
# touch public1.txt
# git add public1.txt
# git commit -m "Added public1.txt"
# 🔹 4. Merge public1 into master
# git checkout master
# git merge public1
# 🔹 5. Merge public2 into master
# git merge public2
# 🔹 6. Edit master.txt in private
# git checkout private
# # edit master.txt manually
# git add master.txt
# git commit -m "Updated master.txt in private"
# 🔹 7. Update public1 & public2 with private code
# git checkout public1
# git merge private
#
# git checkout public2
# git merge private
# 🔹 8. Update master with private
# git checkout master
# git merge private
# 🔹 9. Update private with latest master
# git checkout private
# git merge master

# %% [raw]
# 5🔹 1. Initialize Git Flow
# git init
# git flow init
#
# (Default settings:
# master → production
# develop → development)
#
# 🔹 2. Create feature branch
# git flow feature start feature1
#
# Add file & commit:
#
# touch feature.txt
# git add feature.txt
# git commit -m "Added feature"
# 🔹 3. Finish feature (merge to develop)
# git flow feature finish feature1
#
# Merge develop → master:
#
# git checkout master
# git merge develop
#
# Push:
#
# git push origin master
# git push origin develop
# 🔹 4. Hotfix (urgent.txt on master)
# git flow hotfix start urgentfix
# touch urgent.txt
# git add urgent.txt
# git commit -m "Added urgent fix"
# git flow hotfix finish urgentfix
# git push origin master
# git push origin develop
